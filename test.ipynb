# %%
# Source - https://stackoverflow.com/q/79779187
# Posted by HARSHIL PRAVEEN, modified by community. See post 'Timeline' for change history
# Retrieved 2026-02-09, License - CC BY-SA 4.0

import google.generativeai as genai

genai.configure(api_key="")
model = genai.GenerativeModel("gemini-2.5-flash")

response = model.generate_content("Test prompt")
print(response.text)
# Out:
# Understood! This is a test prompt.
#
# I'm ready to assist. What would you like me to do? Do you have a specific task in mind, or are you just checking for a response?
#
# For example, I can:
# *   Answer a question
# *   Write something (a story, an email, code, a poem, etc.)
# *   Summarize text
# *   Translate languages
# *   Brainstorm ideas
# *   Explain a concept
# *   Or something else entirely!
#
# Just let me know what you need!
